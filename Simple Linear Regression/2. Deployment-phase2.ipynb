# %%
# import pickle library
import pickle

# %%
# Load the saved model
loaded_model = pickle.load(open("finalized_model_slr.sav",'rb'))

# %%
# Predict the output and assign to a variable
result = loaded_model.predict([[13]])
# Out:
# C:\Anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
# display the value
result
# Out:
# array([[148460.78806172]])

# %%
# when you pass the 0 in input the output should match the bias value
result = loaded_model.predict([[0]])
# Out:
# C:\Anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
result
# Out:
# array([[26777.3913412]])
