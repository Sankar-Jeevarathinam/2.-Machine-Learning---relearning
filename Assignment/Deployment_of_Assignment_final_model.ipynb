# %%
import pickle
loaded_model = pickle.load(open("finalized_model_insurance_charges.sav",'rb'))

# %%
result = loaded_model.predict([['54','34','2','1','0']])
# Out:
# C:\Anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(

# %%
result
# Out:
# array([14079.24087156])
